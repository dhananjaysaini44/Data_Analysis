# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"students_dataset.txt")

# %%
print(df)
# Out:
#   Student Department  Year  Marks
# 0    Anuj        CSE     1     85
# 1    Ravi        ECE     2     78
# 2   Priya        CSE     1     92
# 3    Aman         ME     3     66
# 4    Neha        ECE     2     74
# 5   Rahul        CSE     1     88
# 6   Pooja         ME     3     70
# 7   Karan        CSE     2     90
# 8   Sneha        ECE     1     81
# 9   Vikas         ME     3     69

# %%
df1 = df.groupby("Department")
print(df1)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001AED5A9F6B0>

# %%
df1.groups
# Out:
# {'CSE': [0, 2, 5, 7], 'ECE': [1, 4, 8], 'ME': [3, 6, 9]}

# %%
print(df1.sum())
# Out:
#                         Student  Year  Marks
# Department
# CSE         AnujPriyaRahulKaran     5    355
# ECE               RaviNehaSneha     5    233
# ME               AmanPoojaVikas     9    205

# %%
df2 = pd.read_csv("df1_students.txt")
df3 = pd.read_csv("df2_marks.txt")
df2
# Out:
#    Student_ID Student_Name Department
# 0         101         Anuj        CSE
# 1         102         Ravi        ECE
# 2         103        Priya         ME
# 3         104         Aman        CSE
# 4         105         Neha        ECE

# %%
display(df2, df3)
# Out:
#    Student_ID Student_Name Department
# 0         101         Anuj        CSE
# 1         102         Ravi        ECE
# 2         103        Priya         ME
# 3         104         Aman        CSE
# 4         105         Neha        ECE
#    Student_ID  Marks Grade
# 0         103     78     B
# 1         104     85     A
# 2         105     72     B
# 3         106     90    A+
# 4         107     65     C

# %%
df2.merge(df3)
# Out:
#    Student_ID Student_Name Department  Marks Grade
# 0         103        Priya         ME     78     B
# 1         104         Aman        CSE     85     A
# 2         105         Neha        ECE     72     B

# %%
df2.merge(df3, how = "left")
# Out:
#    Student_ID Student_Name Department  Marks Grade
# 0         101         Anuj        CSE    NaN   NaN
# 1         102         Ravi        ECE    NaN   NaN
# 2         103        Priya         ME   78.0     B
# 3         104         Aman        CSE   85.0     A
# 4         105         Neha        ECE   72.0     B

# %%
df2.merge(df3, how = "right")
# Out:
#    Student_ID Student_Name Department  Marks Grade
# 0         103        Priya         ME     78     B
# 1         104         Aman        CSE     85     A
# 2         105         Neha        ECE     72     B
# 3         106          NaN        NaN     90    A+
# 4         107          NaN        NaN     65     C

# %%
df2.merge(df3, how = "outer")
# Out:
#    Student_ID Student_Name Department  Marks Grade
# 0         101         Anuj        CSE    NaN   NaN
# 1         102         Ravi        ECE    NaN   NaN
# 2         103        Priya         ME   78.0     B
# 3         104         Aman        CSE   85.0     A
# 4         105         Neha        ECE   72.0     B
# 5         106          NaN        NaN   90.0    A+
# 6         107          NaN        NaN   65.0     C

# %%
df2.merge(df3, how = "cross")
# Out:
#     Student_ID_x Student_Name Department  Student_ID_y  Marks Grade
# 0            101         Anuj        CSE           103     78     B
# 1            101         Anuj        CSE           104     85     A
# 2            101         Anuj        CSE           105     72     B
# 3            101         Anuj        CSE           106     90    A+
# 4            101         Anuj        CSE           107     65     C
# 5            102         Ravi        ECE           103     78     B
# 6            102         Ravi        ECE           104     85     A
# 7            102         Ravi        ECE           105     72     B
# 8            102         Ravi        ECE           106     90    A+
# 9            102         Ravi        ECE           107     65     C
# 10           103        Priya         ME           103     78     B
# 11           103        Priya         ME           104     85     A
# 12           103        Priya         ME           105     72     B
# 13           103        Priya         ME           106     90    A+
# 14           103        Priya         ME           107     65     C
# 15           104         Aman        CSE           103     78     B
# 16           104         Aman        CSE           104     85     A
# 17           104         Aman        CSE           105     72     B
# 18           104         Aman        CSE           106     90    A+
# 19           104         Aman        CSE           107     65     C
# 20           105         Neha        ECE           103     78     B
# 21           105         Neha        ECE           104     85     A
# 22           105         Neha        ECE           105     72     B
# 23           105         Neha        ECE           106     90    A+
# 24           105         Neha        ECE           107     65     C

# %%
pd.concat([df2, df3], axis = 1)
# Out:
#    Student_ID Student_Name Department  Student_ID  Marks Grade
# 0         101         Anuj        CSE         103     78     B
# 1         102         Ravi        ECE         104     85     A
# 2         103        Priya         ME         105     72     B
# 3         104         Aman        CSE         106     90    A+
# 4         105         Neha        ECE         107     65     C

# %%
pd.concat([df2, df3], ignore_index = 1)
# Out:
#    Student_ID Student_Name Department  Marks Grade
# 0         101         Anuj        CSE    NaN   NaN
# 1         102         Ravi        ECE    NaN   NaN
# 2         103        Priya         ME    NaN   NaN
# 3         104         Aman        CSE    NaN   NaN
# 4         105         Neha        ECE    NaN   NaN
# 5         103          NaN        NaN   78.0     B
# 6         104          NaN        NaN   85.0     A
# 7         105          NaN        NaN   72.0     B
# 8         106          NaN        NaN   90.0    A+
# 9         107          NaN        NaN   65.0     C

# %%
df2.join(df3, lsuffix = "1", rsuffix = "2")
# Out:
#    Student_ID1 Student_Name Department  Student_ID2  Marks Grade
# 0          101         Anuj        CSE          103     78     B
# 1          102         Ravi        ECE          104     85     A
# 2          103        Priya         ME          105     72     B
# 3          104         Aman        CSE          106     90    A+
# 4          105         Neha        ECE          107     65     C

# %%
df2.iloc[1, 2]
# Out:
# 'ECE'

# %%
df2
# Out:
#    Student_ID Student_Name Department
# 0         101         Anuj        CSE
# 1         102         Ravi        ECE
# 2         103        Priya         ME
# 3         104         Aman        CSE
# 4         105         Neha        ECE

# %%
df2.iloc[1:3, 0:4]
# Out:
#    Student_ID Student_Name Department
# 1         102         Ravi        ECE
# 2         103        Priya         ME

# %%
df2.loc[1:3, ["Student_ID", "Student_Name", "Department"]]
# Out:
#    Student_ID Student_Name Department
# 1         102         Ravi        ECE
# 2         103        Priya         ME
# 3         104         Aman        CSE

# %%
df5 = pd.read_csv(r"students_dirty_data.csv")
df5
# Out:
#     Roll     Name   Marks Branch            Email   Join_Date
# 0  101.0     Anuj      85    CSE   anuj@gmail.com  2023-01-10
# 1  102.0    Ravi   Ninety    ECE       ravi@gmail  2023-11-10
# 2  103.0      NaN     -10     ME              NaN  2023/03/15
# 3  104.0      NaN     105    NaN  priya@gmail.com     invalid
# 4  105.0    Priya     NaN    NaN                          NaN
# 5  105.0    Priya      88    CSE   anuj@gmail.com  2024-09-30
# 6    NaN      123      45    cse          invalid  2023-13-01

# %%
df5["Roll"].interpolate(inplace = True)
df5
# Out:
#     Roll     Name   Marks Branch            Email   Join_Date
# 0  101.0     Anuj      85    CSE   anuj@gmail.com  2023-01-10
# 1  102.0    Ravi   Ninety    ECE       ravi@gmail  2023-11-10
# 2  103.0      NaN     -10     ME              NaN  2023/03/15
# 3  104.0      NaN     105    NaN  priya@gmail.com     invalid
# 4  105.0    Priya     NaN    NaN                          NaN
# 5  105.0    Priya      88    CSE   anuj@gmail.com  2024-09-30
# 6  105.0      123      45    cse          invalid  2023-13-01

# %%
df5["Roll"] = pd.to_numeric(df5["Roll"], downcast = "integer")

# %%
df5
# Out:
#    Roll     Name   Marks Branch            Email   Join_Date
# 0   101     Anuj      85    CSE   anuj@gmail.com  2023-01-10
# 1   102    Ravi   Ninety    ECE       ravi@gmail  2023-11-10
# 2   103      NaN     -10     ME              NaN  2023/03/15
# 3   104      NaN     105    NaN  priya@gmail.com     invalid
# 4   105    Priya     NaN    NaN                          NaN
# 5   105    Priya      88    CSE   anuj@gmail.com  2024-09-30
# 6   105      123      45    cse          invalid  2023-13-01

# %%
df5["Name"].replace(np.nan, "Unknown", inplace = True)
df5
# Out:
# C:\Users\DHANANJAY\AppData\Local\Temp\ipykernel_17772\459624352.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df5["Name"].replace(np.nan, "Unknown", inplace = True)
#    Roll     Name   Marks Branch            Email   Join_Date
# 0   101     Anuj      85    CSE   anuj@gmail.com  2023-01-10
# 1   102    Ravi   Ninety    ECE       ravi@gmail  2023-11-10
# 2   103  Unknown     -10     ME              NaN  2023/03/15
# 3   104  Unknown     105    NaN  priya@gmail.com     invalid
# 4   105    Priya     NaN    NaN                          NaN
# 5   105    Priya      88    CSE   anuj@gmail.com  2024-09-30
# 6   105      123      45    cse          invalid  2023-13-01

# %%
df5["Name"].replace("123", "Unknown", inplace = True)
df5
# Out:
# C:\Users\DHANANJAY\AppData\Local\Temp\ipykernel_17772\220311596.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df5["Name"].replace("123", "Unknown", inplace = True)
#    Roll     Name   Marks Branch            Email   Join_Date
# 0   101     Anuj      85    CSE   anuj@gmail.com  2023-01-10
# 1   102    Ravi   Ninety    ECE       ravi@gmail  2023-11-10
# 2   103  Unknown     -10     ME              NaN  2023/03/15
# 3   104  Unknown     105    NaN  priya@gmail.com     invalid
# 4   105    Priya     NaN    NaN                          NaN
# 5   105    Priya      88    CSE   anuj@gmail.com  2024-09-30
# 6   105  Unknown      45    cse          invalid  2023-13-01

# %%
import seaborn as sns

# %%
a = [[76, 23, 45, 65, 11, 90], [1, 2, 3, 0, 0, 0]]
sns.heatmap(a)
# Out:
# <Axes: >
