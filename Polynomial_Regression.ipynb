# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler
from sklearn.metrics import (
    classification_report, confusion_matrix, ConfusionMatrixDisplay, 
    precision_score, recall_score, f1_score, precision_recall_curve
)
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

from imblearn.over_sampling import SMOTE

pd.set_option("display.max_columns", None)
sns.set_theme(style="whitegrid", palette="muted")

# %%
df = pd.read_csv("train.csv")
X = df[["GrLivArea"]]
Y = df["SalePrice"]
X.head()

# %%
lr = LinearRegression()
lr.fit(X, Y)

# %%
y_pred = lr.predict(X)
lr.score(X, Y)

# %%
s = sorted(zip(X["GrLivArea"], Y))
X_sort, Y_sort = zip(*s)

# %%
sns.scatterplot(df, x = "GrLivArea", y = "SalePrice")
plt.plot(X, y_pred, color = "red")

# %%
poly = PolynomialFeatures(degree = 5)

# %%
X_sort = pd.DataFrame(X_sort, columns =["GrLivArea"], index = np.arange(0, 1460))

# %%
X_poly = poly.fit_transform(X_sort)
X_poly.shape

# %%
lr.fit(X_poly, Y_sort)

# %%
y_pred = lr.predict(X_poly)
lr.score(X_poly, Y_sort)

# %%
sns.scatterplot(df, x = "GrLivArea", y = "SalePrice")
plt.plot(X_sort, y_pred, color = "red")

# %%
px.scatter(df, x = "GrLivArea", y = "SalePrice")
